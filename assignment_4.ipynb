# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error as mse, accuracy_score, confusion_matrix, root_mean_squared_error as rmse

# %%
data = pd.read_csv("ServiceTrain.csv")

# %%
data["Service"] = [1 if x=="Yes" else 0 for x in data["Service"]]

# %%
x = data.drop(["Service"], axis=1)
y = data["Service"]
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    0
# Name: Service, dtype: int64

# %%
trainX, testX, trainY, testY = tts(x, y, test_size=0.3, random_state=0)

# %%
x['OilQual'].value_counts()
# Out:
# OilQual
# 104.388821    48
# 4.987185      28
# 45.533338     24
# 26.765516     17
# 62.413282     16
#               ..
# 62.163282      1
# 104.928821     1
# 5.597185       1
# 102.388821     1
# 26.215516      1
# Name: count, Length: 144, dtype: int64

# %%
logi = LogisticRegression()
logi.fit(trainX, trainY)
# Out:
# LogisticRegression()

# %%
pred = logi.predict(testX)

# %%
confusion_matrix(testY, pred)
# Out:
# array([[65,  2],
#        [ 3, 25]], dtype=int64)

# %%
accuracy_score(testY, pred)
# Out:
# 0.9473684210526315

# %%
report = pd.read_csv("GHI_report.csv")

# %%
report.head()
# Out:
#    Economy      Fam   Health  Freedom  H_Score
# 0  1.39651  1.34951  0.94143  0.66557    7.587
# 1  1.30232  1.40223  0.94784  0.62877    7.561
# 2  1.32548  1.36058  0.87464  0.64938    7.527
# 3  1.45900  1.33095  0.88521  0.66973    7.522
# 4  1.32629  1.32261  0.90563  0.63297    7.427

# %%
x = report.drop(["H_Score"], axis=1)
y = report["H_Score"]

# %%
trainX, testX, trainY, testY = tts(x, y, test_size=0.25, random_state=1)

# %%
lgr = LinearRegression(fit_intercept=True)
model = lgr.fit(trainX, trainY)

# %%
pred = lgr.predict(testX)
error = rmse(testY, pred)
error
# Out:
# 0.45810404395107507

# %%
base_pred = np.repeat(np.mean(testY), len(testY))

# %%
pred = lgr.predict(testX)
error = rmse(testY, base_pred)
error
# Out:
# 1.063864335512287
